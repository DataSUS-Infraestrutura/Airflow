# %% [markdown]
# ## **Analisando Arquivos de DO**

# %%
import pandas as pd

df = pd.read_parquet('/home/jamilsonfs/airflow/dags/SIM/tmp/PARQUET/DOPB2021.parquet')
df
# Out:
#       Tipo de Óbito Data do Óbito Hora do Óbito Naturalidade  \
# 0         Não Fetal      16082021         1130           825
# 1         Não Fetal      25022021         0840           825
# 2         Não Fetal      01032021         1615           825
# 3         Não Fetal      03032021         1400           825
# 4         Não Fetal      12032021         2100           825
# ...             ...           ...           ...          ...
# 34673     Não Fetal      11072021         0220           825
# 34674     Não Fetal      10072021         1640           825
# 34675     Não Fetal      10072021         1635           825
# 34676     Não Fetal      11072021         0245           825
# 34677     Não Fetal      06072021         0316           825
#
#       Data de Nascimento     Idade    Sexo Raça/Cor Estado Civil Escolaridade  \
# 0               06061920  101 anos   Homem    Parda        Viúvo      Nenhuma
# 1               11011961   60 anos  Mulher    Parda       Casado
# ...

# %%
df['CAUSABAS']
# Out:
# 0           Outras Doenças Pulmonares Obstrutivas Crônicas
# 1                    Diabetes Mellitus Insulino-dependente
# 2                                        Leucemia Mielóide
# 3                               Infarto Agudo do Miocárdio
# 4        Doenças Por Vírus, de Localização Não Especifi...
#                                ...
# 34673          Outras Doenças Isquêmicas Agudas do Coração
# 34674          Outras Doenças Isquêmicas Agudas do Coração
# 34675                         Doença Cardíaca Hipertensiva
# 34676                   Diabetes Mellitus Não Especificado
# 34677                Outras Doenças Vasculares Periféricas
# Name: CAUSABAS, Length: 34678, dtype: object
